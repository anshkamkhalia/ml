# %%
import pandas as pd       
import numpy as np       
import random            
from datetime import timedelta, datetime

# %%
import random

high_zero_death_cases = []
high_zero_death_deaths = []
high_zero_death_tests = []

for _ in range(300):
    case = 0.0 if random.random() < 0.1 else round(np.random.normal(2500, 800), 1)
    
    death = 0.0 if random.random() < 0.65 else round(np.random.normal(400, 100), 1)
    
    if random.random() < 0.15:
        test = np.nan
    else:
        test = round(np.random.normal(30000, 10000), 1)

    high_zero_death_cases.append(max(0.0, case))
    high_zero_death_deaths.append(max(0.0, death))
    high_zero_death_tests.append(test)

df_high_zero_deaths = pd.DataFrame({
    "date": [d.strftime('%Y-%m-%d') for d in dates],
    "new_cases": high_zero_death_cases,
    "new_deaths": high_zero_death_deaths,
    "new_tests": high_zero_death_tests
})

high_zero_csv_path = "covid_data.csv"
df_high_zero_deaths.to_csv(high_zero_csv_path, index=False)

high_zero_csv_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 22
#      18     high_zero_death_deaths.append(max(0.0, death))
#      19     high_zero_death_tests.append(test)
#      21 df_high_zero_deaths = pd.DataFrame({
# ---> 22     "date": [d.strftime('%Y-%m-%d') for d in dates],
#      23     "new_cases": high_zero_death_cases,
#      24     "new_deaths": high_zero_death_deaths,
#      25     "new_tests": high_zero_death_tests
#      26 })
#      28 high_zero_csv_path = "covid_data.csv"
#      29 df_high_zero_deaths.to_csv(high_zero_csv_path, index=False)
#
# NameError: name 'dates' is not defined

# %%
df = pd.read_csv("covid_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("covid_data.csv")
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-01-01     2751.6         0.0    46108.8
# 1    2020-01-02        0.0       505.6    18816.8
# 2    2020-01-03     1878.3         0.0    39944.4
# 3    2020-01-04     1442.8       460.0    23216.5
# 4    2020-01-05     2907.2         0.0    35382.6
# ..          ...        ...         ...        ...
# 295  2020-10-22     1508.5         0.0    29411.5
# 296  2020-10-23     1880.9         0.0    17018.2
# 297  2020-10-24     2162.6       462.3    39517.7
# 298  2020-10-25     2444.1         0.0    32900.3
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [300 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        300 non-null    object
#  1   new_cases   300 non-null    float64
#  2   new_deaths  300 non-null    float64
#  3   new_tests   258 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   300.000000  300.000000    258.000000
# mean   2265.527333  130.379667  29623.168217
# std     987.315914  194.425424  10548.958853
# min       0.000000    0.000000   2608.600000
# 25%    1701.075000    0.000000  22622.425000
# 50%    2324.250000    0.000000  29005.350000
# 75%    2886.175000  325.750000  36851.400000
# max    4402.600000  652.900000  55962.500000

# %%
df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
df.shape
# Out:
# (300, 4)

# %%
df["new_cases"]
# Out:
# 0      2751.6
# 1         0.0
# 2      1878.3
# 3      1442.8
# 4      2907.2
#         ...
# 295    1508.5
# 296    1880.9
# 297    2162.6
# 298    2444.1
# 299    2991.6
# Name: new_cases, Length: 300, dtype: float64

# %%
df.new_cases
# Out:
# 0      2751.6
# 1         0.0
# 2      1878.3
# 3      1442.8
# 4      2907.2
#         ...
# 295    1508.5
# 296    1880.9
# 297    2162.6
# 298    2444.1
# 299    2991.6
# Name: new_cases, Length: 300, dtype: float64

# %%
df["date"]
# Out:
# 0      2020-01-01
# 1      2020-01-02
# 2      2020-01-03
# 3      2020-01-04
# 4      2020-01-05
#           ...
# 295    2020-10-22
# 296    2020-10-23
# 297    2020-10-24
# 298    2020-10-25
# 299    2020-10-26
# Name: date, Length: 300, dtype: object

# %%
type(df.date)
# Out:
# pandas.core.series.Series

# %%
df["date"][124]
# Out:
# '2020-05-04'

# %%
df.at[124, "date"]
# Out:
# '2020-05-04'

# %%
date_case_df = df[["date", "new_cases"]]
date_case_df
# Out:
#            date  new_cases
# 0    2020-01-01     2751.6
# 1    2020-01-02        0.0
# 2    2020-01-03     1878.3
# 3    2020-01-04     1442.8
# 4    2020-01-05     2907.2
# ..          ...        ...
# 295  2020-10-22     1508.5
# 296  2020-10-23     1880.9
# 297  2020-10-24     2162.6
# 298  2020-10-25     2444.1
# 299  2020-10-26     2991.6
#
# [300 rows x 2 columns]

# %%
copy_of_df = df.copy()
copy_of_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-01-01     2751.6         0.0    46108.8
# 1    2020-01-02        0.0       505.6    18816.8
# 2    2020-01-03     1878.3         0.0    39944.4
# 3    2020-01-04     1442.8       460.0    23216.5
# 4    2020-01-05     2907.2         0.0    35382.6
# ..          ...        ...         ...        ...
# 295  2020-10-22     1508.5         0.0    29411.5
# 296  2020-10-23     1880.9         0.0    17018.2
# 297  2020-10-24     2162.6       462.3    39517.7
# 298  2020-10-25     2444.1         0.0    32900.3
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [300 rows x 4 columns]

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-01-01     2751.6         0.0    46108.8
# 1    2020-01-02        0.0       505.6    18816.8
# 2    2020-01-03     1878.3         0.0    39944.4
# 3    2020-01-04     1442.8       460.0    23216.5
# 4    2020-01-05     2907.2         0.0    35382.6
# ..          ...        ...         ...        ...
# 295  2020-10-22     1508.5         0.0    29411.5
# 296  2020-10-23     1880.9         0.0    17018.2
# 297  2020-10-24     2162.6       462.3    39517.7
# 298  2020-10-25     2444.1         0.0    32900.3
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [300 rows x 4 columns]

# %%
df.loc[296]
# Out:
# date          2020-10-23
# new_cases         1880.9
# new_deaths           0.0
# new_tests        17018.2
# Name: 296, dtype: object

# %%
df.new_tests.first_valid_index()
# Out:
# 0

# %%
df.loc[0]
# Out:
# date          2020-01-01
# new_cases         2751.6
# new_deaths           0.0
# new_tests        46108.8
# Name: 0, dtype: object

# %%
# %%time
df.sample(10)
# Out:
# CPU times: total: 0 ns
# Wall time: 288 μs
#            date  new_cases  new_deaths  new_tests
# 40   2020-02-10     2467.6       345.7    36889.7
# 64   2020-03-05     1725.8         0.0    42012.1
# 252  2020-09-09     2878.6         0.0    23249.2
# 154  2020-06-03     3779.2         0.0    51399.2
# 107  2020-04-17     1322.6         0.0    41103.4
# 254  2020-09-11     1186.4         0.0    21596.7
# 55   2020-02-25     1653.1       456.5    39979.8
# 229  2020-08-17     1569.1         0.0    25985.6
# 167  2020-06-16     2504.2         0.0    48849.7
# 50   2020-02-20        0.0         0.0    23362.5

# %%
df.new_cases
# Out:
# 0      2751.6
# 1         0.0
# 2      1878.3
# 3      1442.8
# 4      2907.2
#         ...
# 295    1508.5
# 296    1880.9
# 297    2162.6
# 298    2444.1
# 299    2991.6
# Name: new_cases, Length: 300, dtype: float64

# %%
print(df.new_cases)
# Out:
# 0      2751.6
# 1         0.0
# 2      1878.3
# 3      1442.8
# 4      2907.2
#         ...
# 295    1508.5
# 296    1880.9
# 297    2162.6
# 298    2444.1
# 299    2991.6
# Name: new_cases, Length: 300, dtype: float64

# %%
new_cases_sum = df.new_cases.sum()
new_cases_sum
# Out:
# np.float64(679658.2)

# %%
new_deaths_sum = df.new_deaths.sum()
new_deaths_sum
# Out:
# np.float64(39113.9)

# %%
death_rate = new_deaths_sum/new_cases_sum
death_rate
# Out:
# np.float64(0.057549368197132036)

# %%
inital_tests = 935310
total_tests = inital_tests + df.new_tests.sum()
total_tests
# Out:
# np.float64(8578087.399999999)

# %%
positive_rate = new_cases_sum/total_tests
positive_rate
# Out:
# np.float64(0.07923190430538164)

# %%
high_new_cases = df[df.new_cases > 1000]
high_new_cases
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-01-01     2751.6         0.0    46108.8
# 2    2020-01-03     1878.3         0.0    39944.4
# 3    2020-01-04     1442.8       460.0    23216.5
# 4    2020-01-05     2907.2         0.0    35382.6
# 6    2020-01-07     2799.6         0.0    22531.8
# ..          ...        ...         ...        ...
# 295  2020-10-22     1508.5         0.0    29411.5
# 296  2020-10-23     1880.9         0.0    17018.2
# 297  2020-10-24     2162.6       462.3    39517.7
# 298  2020-10-25     2444.1         0.0    32900.3
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [274 rows x 4 columns]

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 100):
    display(df[df.new_cases > 1000])
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-01-01     2751.6         0.0    46108.8
# 2    2020-01-03     1878.3         0.0    39944.4
# 3    2020-01-04     1442.8       460.0    23216.5
# 4    2020-01-05     2907.2         0.0    35382.6
# 6    2020-01-07     2799.6         0.0    22531.8
# ..          ...        ...         ...        ...
# 295  2020-10-22     1508.5         0.0    29411.5
# 296  2020-10-23     1880.9         0.0    17018.2
# 297  2020-10-24     2162.6       462.3    39517.7
# 298  2020-10-25     2444.1         0.0    32900.3
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [274 rows x 4 columns]

# %%
positive_rate
# Out:
# np.float64(0.07923190430538164)

# %%
high_ratio_df = df[df.new_cases / df.new_tests > positive_rate]

# %%
high_ratio_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 4    2020-01-05     2907.2         0.0    35382.6
# 6    2020-01-07     2799.6         0.0    22531.8
# 11   2020-01-12     2614.2       410.3    28234.0
# 16   2020-01-17     3614.4       322.3    27733.2
# 17   2020-01-18     1915.8         0.0    14409.0
# ..          ...        ...         ...        ...
# 287  2020-10-14     3133.9         0.0    26977.3
# 292  2020-10-19     3388.3         0.0    33240.5
# 294  2020-10-21     3449.1         0.0     9243.4
# 296  2020-10-23     1880.9         0.0    17018.2
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [119 rows x 4 columns]

# %%
df["positive_rate"] = df.new_cases / df.new_tests

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 0    2020-01-01     2751.6         0.0    46108.8       0.059676
# 1    2020-01-02        0.0       505.6    18816.8       0.000000
# 2    2020-01-03     1878.3         0.0    39944.4       0.047023
# 3    2020-01-04     1442.8       460.0    23216.5       0.062145
# 4    2020-01-05     2907.2         0.0    35382.6       0.082165
# ..          ...        ...         ...        ...            ...
# 295  2020-10-22     1508.5         0.0    29411.5       0.051289
# 296  2020-10-23     1880.9         0.0    17018.2       0.110523
# 297  2020-10-24     2162.6       462.3    39517.7       0.054725
# 298  2020-10-25     2444.1         0.0    32900.3       0.074288
# 299  2020-10-26     2991.6       141.3    36404.6       0.082176
#
# [300 rows x 5 columns]

# %%
df.drop(columns=["positive_rate"], inplace=True)

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-01-01     2751.6         0.0    46108.8
# 1    2020-01-02        0.0       505.6    18816.8
# 2    2020-01-03     1878.3         0.0    39944.4
# 3    2020-01-04     1442.8       460.0    23216.5
# 4    2020-01-05     2907.2         0.0    35382.6
# ..          ...        ...         ...        ...
# 295  2020-10-22     1508.5         0.0    29411.5
# 296  2020-10-23     1880.9         0.0    17018.2
# 297  2020-10-24     2162.6       462.3    39517.7
# 298  2020-10-25     2444.1         0.0    32900.3
# 299  2020-10-26     2991.6       141.3    36404.6
#
# [300 rows x 4 columns]

# %%
df.sort_values("new_cases", ascending=False).head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 22   2020-01-23     4402.6       419.7    25291.6
# 212  2020-07-31     4313.1         0.0    37092.1
# 92   2020-04-02     4302.0       299.0        NaN
# 188  2020-07-07     4279.1       416.7    34343.2
# 239  2020-08-27     4217.1         0.0    51364.1
# 120  2020-04-30     4215.2       350.9        NaN
# 111  2020-04-21     4169.8         0.0    25107.6
# 30   2020-01-31     4134.8         0.0    33430.7
# 89   2020-03-30     4119.7         0.0        NaN
# 168  2020-06-17     3983.2       280.1    22014.8

# %%
df.sort_values("new_deaths", ascending=False).head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 160  2020-06-09     2048.9       652.9        NaN
# 104  2020-04-14     3832.6       600.4    11969.0
# 79   2020-03-20     1717.7       584.3    44149.0
# 149  2020-05-29     1669.5       581.7    48912.9
# 278  2020-10-05     2885.0       579.8        NaN
# 237  2020-08-25     2283.9       574.5    28194.4
# 97   2020-04-07     2269.7       532.9    18649.4
# 236  2020-08-24     1628.7       528.0    29011.8
# 99   2020-04-09     2441.9       515.6    26966.7
# 1    2020-01-02        0.0       505.6    18816.8

# %%
df.sort_values("new_cases").head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 1    2020-01-02        0.0       505.6    18816.8
# 5    2020-01-06        0.0         0.0        NaN
# 232  2020-08-20        0.0         0.0    22839.4
# 253  2020-09-10        0.0         0.0    42285.1
# 70   2020-03-11        0.0         0.0    21955.6
# 222  2020-08-10        0.0         0.0    19090.5
# 216  2020-08-04        0.0         0.0    37861.8
# 50   2020-02-20        0.0         0.0    23362.5
# 206  2020-07-25        0.0         0.0    20880.4
# 201  2020-07-20        0.0         0.0    38101.7

# %%
df.date
# Out:
# 0      2020-01-01
# 1      2020-01-02
# 2      2020-01-03
# 3      2020-01-04
# 4      2020-01-05
#           ...
# 295    2020-10-22
# 296    2020-10-23
# 297    2020-10-24
# 298    2020-10-25
# 299    2020-10-26
# Name: date, Length: 300, dtype: object

# %%
df["date"] = pd.to_datetime(df.date)

# %%
df.date
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 295   2020-10-22
# 296   2020-10-23
# 297   2020-10-24
# 298   2020-10-25
# 299   2020-10-26
# Name: date, Length: 300, dtype: datetime64[ns]

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df["year"] = pd.DatetimeIndex(df.date).year
df["month"] = pd.DatetimeIndex(df.date).month
df["day"] = pd.DatetimeIndex(df.date).day
df["weekday"] = pd.DatetimeIndex(df.date).weekday

# %%
df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests', 'year', 'month', 'day',
#        'weekday'],
#       dtype='object')

# %%
df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2020-01-01     2751.6         0.0    46108.8  2020      1    1        2
# 1   2020-01-02        0.0       505.6    18816.8  2020      1    2        3
# 2   2020-01-03     1878.3         0.0    39944.4  2020      1    3        4
# 3   2020-01-04     1442.8       460.0    23216.5  2020      1    4        5
# 4   2020-01-05     2907.2         0.0    35382.6  2020      1    5        6
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 295 2020-10-22     1508.5         0.0    29411.5  2020     10   22        3
# 296 2020-10-23     1880.9         0.0    17018.2  2020     10   23        4
# 297 2020-10-24     2162.6       462.3    39517.7  2020     10   24        5
# 298 2020-10-25     2444.1         0.0    32900.3  2020     10   25        6
# 299 2020-10-26     2991.6       141.3    36404.6  2020     10   26        0
#
# [300 rows x 8 columns]

# %%
df.new_cases.mean()
# Out:
# np.float64(2265.527333333333)

# %%
df[df.weekday == 6].new_cases.mean()
# Out:
# np.float64(2464.248837209303)

# %%
covid_month_df = df.groupby("month")[['new_cases','new_tests','new_deaths']].sum()

# %%
covid_month_df
# Out:
#        new_cases  new_tests  new_deaths
# month
# 1        73457.1   879446.5      3728.9
# 2        70164.7   806713.2      3680.4
# 3        75353.1   777244.1      2800.4
# 4        67510.8   829565.1      5929.2
# 5        66483.6   718903.0      5469.5
# 6        67555.6   725105.3      3701.7
# 7        60711.6   717371.0      3191.8
# 8        68315.5   786039.6      4939.8
# 9        67553.0   723347.0      2912.3
# 10       62553.2   679042.6      2759.9

# %%
df.new_cases.plot()
df.new_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.set_index("date",inplace=True)

# %%
df
# Out:
#             new_cases  new_deaths  new_tests  year  month  day  weekday
# date
# 2020-01-01     2751.6         0.0    46108.8  2020      1    1        2
# 2020-01-02        0.0       505.6    18816.8  2020      1    2        3
# 2020-01-03     1878.3         0.0    39944.4  2020      1    3        4
# 2020-01-04     1442.8       460.0    23216.5  2020      1    4        5
# 2020-01-05     2907.2         0.0    35382.6  2020      1    5        6
# ...               ...         ...        ...   ...    ...  ...      ...
# 2020-10-22     1508.5         0.0    29411.5  2020     10   22        3
# 2020-10-23     1880.9         0.0    17018.2  2020     10   23        4
# 2020-10-24     2162.6       462.3    39517.7  2020     10   24        5
# 2020-10-25     2444.1         0.0    32900.3  2020     10   25        6
# 2020-10-26     2991.6       141.3    36404.6  2020     10   26        0
#
# [300 rows x 7 columns]
