# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline

# %%
X_train = pd.read_csv('playground_series_data/train.csv')
X_test = pd.read_csv('playground_series_data/test.csv')

# %%
X_train.shape
# Out:
# (18524, 9)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val = train_test_split(X_train, random_state=42, test_size=0.25)

# %%
X_val
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 13209  13209               NaN         No                      9.0
# 2740    2740               0.0         No                      9.0
# 10249  10249               3.0         No                      8.0
# 7608    7608               1.0         No                      7.0
# 10528  10528               0.0         No                      6.0
# ...      ...               ...        ...                      ...
# 7822    7822               2.0        NaN                      8.0
# 8270    8270               1.0        NaN                      7.0
# 2453    2453               NaN         No                      4.0
# 7975    7975               1.0         No                      7.0
# 14167  14167               0.0         No                      9.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 13209            7.0                        No                  8.0
# ...

# %%
X_train.head()
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 11123  11123               2.0         No                      4.0
# 360      360               4.0        Yes                      3.0
# 15844  15844               2.0         No                      8.0
# 15624  15624               4.0         No                      8.0
# 6466    6466               2.0         No                      9.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 11123            5.0                        No                  6.0
# 360              2.0                       Yes                  2.0
# 15844            4.0                        No                 15.0
# 15624            4.0                        No                 11.0
# 6466             3.0                        No                 10.0
#
#        Post_frequency Personality
# 11123             5.0   Extrovert
# 360               3.0   Introvert
# 15844             8.0   Extrovert
# ...

# %%
X_train.tail()
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 11284  11284               9.0        NaN                      1.0
# 11964  11964               3.0         No                      6.0
# 5390    5390               3.0        NaN                      7.0
# 860      860               3.0         No                      4.0
# 15795  15795               0.0         No                      3.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 11284            3.0                       Yes                  5.0
# 11964            6.0                        No                  NaN
# 5390             3.0                        No                 14.0
# 860              NaN                        No                  9.0
# 15795            5.0                        No                 14.0
#
#        Post_frequency Personality
# 11284             3.0   Introvert
# 11964             3.0   Extrovert
# 5390              8.0   Extrovert
# ...

# %%
X_train.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  13893.000000      12992.000000             13005.000000   12763.000000
# mean    9271.795149          3.148784                 5.246521       4.044034
# std     5360.915939          3.004646                 2.760674       2.063087
# min        1.000000          0.000000                 0.000000       0.000000
# 25%     4612.000000          1.000000                 3.000000       3.000000
# 50%     9305.000000          2.000000                 5.000000       4.000000
# 75%    13933.000000          4.000000                 8.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         13093.000000    12953.000000
# mean              8.027266        4.976453
# std               4.223489        2.873435
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
X_train.shape
# Out:
# (13893, 9)

# %%
X_test.shape
# Out:
# (6175, 8)

# %%
X_train.isna().sum()
# Out:
# id                              0
# Time_spent_Alone              901
# Stage_fear                   1418
# Social_event_attendance       888
# Going_outside                1130
# Drained_after_socializing     863
# Friends_circle_size           800
# Post_frequency                940
# Personality                     0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# id                             0
# Time_spent_Alone             425
# Stage_fear                   598
# Social_event_attendance      397
# Going_outside                466
# Drained_after_socializing    432
# Friends_circle_size          350
# Post_frequency               408
# dtype: int64

# %%
X_train.drop('id', axis=1, inplace=True)
X_val.drop('id', axis=1, inplace=True)

# %%
X_val
# Out:
#        Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 13209               NaN         No                      9.0            7.0
# 2740                0.0         No                      9.0            5.0
# 10249               3.0         No                      8.0            7.0
# 7608                1.0         No                      7.0            NaN
# 10528               0.0         No                      6.0            4.0
# ...                 ...        ...                      ...            ...
# 7822                2.0        NaN                      8.0            3.0
# 8270                1.0        NaN                      7.0            4.0
# 2453                NaN         No                      4.0            6.0
# 7975                1.0         No                      7.0            7.0
# 14167               0.0         No                      9.0            4.0
#
# ...

# %%
X_train_target = X_train['Personality']
X_val_target = X_val['Personality']

# %%
X_val_target
# Out:
# 13209    Extrovert
# 2740     Extrovert
# 10249    Extrovert
# 7608     Extrovert
# 10528    Extrovert
#            ...
# 7822     Extrovert
# 8270     Extrovert
# 2453     Extrovert
# 7975     Extrovert
# 14167    Extrovert
# Name: Personality, Length: 4631, dtype: object

# %%
X_train_target
# Out:
# 11123    Extrovert
# 360      Introvert
# 15844    Extrovert
# 15624    Extrovert
# 6466     Extrovert
#            ...
# 11284    Introvert
# 11964    Extrovert
# 5390     Extrovert
# 860      Extrovert
# 15795    Extrovert
# Name: Personality, Length: 13893, dtype: object

# %%
X_train.drop('Personality', axis=1, inplace=True)
X_val.drop('Personality', axis=1, inplace=True)

# %%
X_train
# Out:
#        Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 11123               2.0         No                      4.0            5.0
# 360                 4.0        Yes                      3.0            2.0
# 15844               2.0         No                      8.0            4.0
# 15624               4.0         No                      8.0            4.0
# 6466                2.0         No                      9.0            3.0
# ...                 ...        ...                      ...            ...
# 11284               9.0        NaN                      1.0            3.0
# 11964               3.0         No                      6.0            6.0
# 5390                3.0        NaN                      7.0            3.0
# 860                 3.0         No                      4.0            NaN
# 15795               0.0         No                      3.0            5.0
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency
# ...

# %%
X_test_id = X_test['id']
X_test_id
# Out:
# 0       18524
# 1       18525
# 2       18526
# 3       18527
# 4       18528
#         ...
# 6170    24694
# 6171    24695
# 6172    24696
# 6173    24697
# 6174    24698
# Name: id, Length: 6175, dtype: int64

# %%
X_test.drop('id', axis=1, inplace=True)

# %%
X_test
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  3.0         No                      7.0            4.0
# 1                  NaN        Yes                      0.0            0.0
# 2                  3.0         No                      5.0            6.0
# 3                  3.0         No                      4.0            4.0
# 4                  9.0        Yes                      1.0            2.0
# ...                ...        ...                      ...            ...
# 6170               3.0         No                      5.0            5.0
# 6171               8.0        Yes                      2.0            1.0
# 6172               2.0         No                      4.0            3.0
# 6173               3.0         No                      4.0            4.0
# 6174               NaN        Yes                      1.0            1.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency
# ...

# %%
X_train
# Out:
#        Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 11123               2.0         No                      4.0            5.0
# 360                 4.0        Yes                      3.0            2.0
# 15844               2.0         No                      8.0            4.0
# 15624               4.0         No                      8.0            4.0
# 6466                2.0         No                      9.0            3.0
# ...                 ...        ...                      ...            ...
# 11284               9.0        NaN                      1.0            3.0
# 11964               3.0         No                      6.0            6.0
# 5390                3.0        NaN                      7.0            3.0
# 860                 3.0         No                      4.0            NaN
# 15795               0.0         No                      3.0            5.0
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency
# ...

# %%
numeric_cols = X_train.select_dtypes(include=np.number).columns

# %%
numeric_cols
# Out:
# Index(['Time_spent_Alone', 'Social_event_attendance', 'Going_outside',
#        'Friends_circle_size', 'Post_frequency'],
#       dtype='object')

# %%
categorical_cols = X_train.select_dtypes(include='object').columns

# %%
categorical_cols
# Out:
# Index(['Stage_fear', 'Drained_after_socializing'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
# ?SimpleImputer
# Out:
# Init signature:
# SimpleImputer(
#     *,
#     missing_values=nan,
#     strategy='mean',
#     fill_value=None,
#     copy=True,
#     add_indicator=False,
#     keep_empty_features=False,
# )
# Docstring:
# Univariate imputer for completing missing values with simple strategies.
#
# Replace missing values using a descriptive statistic (e.g. mean, median, or
# most frequent) along each column, or using a constant value.
#
# Read more in the :ref:`User Guide <impute>`.
#
# .. versionadded:: 0.20
#    `SimpleImputer` replaces the previous `sklearn.preprocessing.Imputer`
#    estimator which is now removed.
#
# Parameters
# ----------
# missing_values : int, float, str, np.nan, None or pandas.NA, default=np.nan
#     The placeholder for the missing values. All occurrences of
#     `missing_values` will be imputed. For pandas' dataframes with
#     nullable integer dtypes with missing values, `missing_values`
#     can be set to either `np.nan` or `pd.NA`.
#
# ...

# %%
imputer = SimpleImputer(copy=False)

# %%
imputer.fit(X_train[numeric_cols])
# Out:
# SimpleImputer(copy=False)

# %%
X_train[numeric_cols] = imputer.transform(X_train[numeric_cols])
X_val[numeric_cols] = imputer.transform(X_val[numeric_cols])
X_test[numeric_cols] = imputer.transform(X_test[numeric_cols])

# %%
X_train[numeric_cols].isna().sum()
# Out:
# Time_spent_Alone           0
# Social_event_attendance    0
# Going_outside              0
# Friends_circle_size        0
# Post_frequency             0
# dtype: int64

# %%
X_test[numeric_cols].isna().sum()
# Out:
# Time_spent_Alone           0
# Social_event_attendance    0
# Going_outside              0
# Friends_circle_size        0
# Post_frequency             0
# dtype: int64

# %%
X_val
# Out:
#        Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 13209          3.148784         No                      9.0       7.000000
# 2740           0.000000         No                      9.0       5.000000
# 10249          3.000000         No                      8.0       7.000000
# 7608           1.000000         No                      7.0       4.044034
# 10528          0.000000         No                      6.0       4.000000
# ...                 ...        ...                      ...            ...
# 7822           2.000000        NaN                      8.0       3.000000
# 8270           1.000000        NaN                      7.0       4.000000
# 2453           3.148784         No                      4.0       6.000000
# 7975           1.000000         No                      7.0       7.000000
# 14167          0.000000         No                      9.0       4.000000
#
#       Drained_after_socializing  Friends_circle_size  Post_frequency
# ...

# %%
key = {"No": 0, "Yes": 1, np.nan: 0}
X_train[categorical_cols[0]] = X_train[categorical_cols[0]].map(key)
X_train[categorical_cols[1]] = X_train[categorical_cols[1]].map(key)

# %%
X_train.isna().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# dtype: int64

# %%
X_test[categorical_cols[0]] = X_test[categorical_cols[0]].map(key)
X_test[categorical_cols[1]] = X_test[categorical_cols[1]].map(key)

# %%
X_val[categorical_cols[0]] = X_val[categorical_cols[0]].map(key)
X_val[categorical_cols[1]] = X_val[categorical_cols[1]].map(key)

# %%
X_train
# Out:
#        Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 11123               2.0           0                      4.0       5.000000
# 360                 4.0           1                      3.0       2.000000
# 15844               2.0           0                      8.0       4.000000
# 15624               4.0           0                      8.0       4.000000
# 6466                2.0           0                      9.0       3.000000
# ...                 ...         ...                      ...            ...
# 11284               9.0           0                      1.0       3.000000
# 11964               3.0           0                      6.0       6.000000
# 5390                3.0           0                      7.0       3.000000
# 860                 3.0           0                      4.0       4.044034
# 15795               0.0           0                      3.0       5.000000
#
# ...

# %%
X_val.isna().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# ?DecisionTreeClassifier
# Out:
# Init signature:
# DecisionTreeClassifier(
#     *,
#     criterion='gini',
#     splitter='best',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features=None,
#     random_state=None,
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     class_weight=None,
#     ccp_alpha=0.0,
#     monotonic_cst=None,
# )
# Docstring:
# A decision tree classifier.
#
# Read more in the :ref:`User Guide <tree>`.
#
# Parameters
# ----------
# criterion : {"gini", "entropy", "log_loss"}, default="gini"
#     The function to measure the quality of a split. Supported criteria are
#     "gini" for the Gini impurity and "log_loss" and "entropy" both for the
#     Shannon information gain, see :ref:`tree_mathematical_formulation`.
#
# splitter : {"best", "random"}, default="best"
#     The strategy used to choose the split at each node. Supported
#     strategies are "best" to choose the best split and "random" to choose
# ...

# %%
len(X_train)
# Out:
# 13893

# %%
X_train
# Out:
#        Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 11123               2.0           0                      4.0       5.000000
# 360                 4.0           1                      3.0       2.000000
# 15844               2.0           0                      8.0       4.000000
# 15624               4.0           0                      8.0       4.000000
# 6466                2.0           0                      9.0       3.000000
# ...                 ...         ...                      ...            ...
# 11284               9.0           0                      1.0       3.000000
# 11964               3.0           0                      6.0       6.000000
# 5390                3.0           0                      7.0       3.000000
# 860                 3.0           0                      4.0       4.044034
# 15795               0.0           0                      3.0       5.000000
#
# ...

# %%
# %%time
tree = DecisionTreeClassifier(max_depth=9).fit(X_train, X_train_target)
# Out:
# CPU times: user 13.6 ms, sys: 652 μs, total: 14.2 ms
# Wall time: 13.8 ms

# %%
from sklearn.metrics import accuracy_score

# %%
preds = tree.predict(X_train)
accuracy_score(X_train_target, preds)
# Out:
# 0.9727200748578421

# %%
preds = tree.predict(X_val)
accuracy_score(X_val_target, preds)
# Out:
# 0.9656661628158065

# %%
tree.get_depth()
# Out:
# 9

# %%
from sklearn.tree import plot_tree
plot_tree(tree, filled=True)
# Out:
# [Text(0.6132514312977099, 0.95, 'x[4] <= 0.5\ngini = 0.385\nsamples = 13893\nvalue = [10280, 3613]'),
#  Text(0.36963263358778625, 0.85, 'x[1] <= 0.5\ngini = 0.127\nsamples = 10836\nvalue = [10098, 738]'),
#  Text(0.4914420324427481, 0.8999999999999999, 'True  '),
#  Text(0.223043893129771, 0.75, 'x[0] <= 6.5\ngini = 0.046\nsamples = 10320\nvalue = [10078.0, 242.0]'),
#  Text(0.10830152671755726, 0.65, 'x[2] <= 0.5\ngini = 0.041\nsamples = 10259\nvalue = [10044.0, 215.0]'),
#  Text(0.030534351145038167, 0.55, 'x[3] <= 5.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.022900763358778626, 0.45, 'x[3] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.015267175572519083, 0.35, 'x[0] <= 2.074\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.007633587786259542, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.022900763358778626, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
preds = tree.predict(X_test)

# %%
preds
# Out:
# array(['Extrovert', 'Introvert', 'Extrovert', ..., 'Extrovert',
#        'Extrovert', 'Introvert'], shape=(6175,), dtype=object)

# %%
import pandas as pd

submission = pd.DataFrame({
    "id": X_test_id,        # same order as in test.csv
    "Personality": preds        # your model's predictions
})

submission.to_csv("submission.csv", index=False)

# %%
tree.feature_importances_
# Out:
# array([0.01139435, 0.18686771, 0.00623651, 0.00332086, 0.78403917,
#        0.00507083, 0.00307057])

# %%
importance_df = pd.DataFrame({
    "feature":list(X_train.columns),
    "importance":list(tree.feature_importances_)
})

# %%
importance_df
# Out:
#                      feature  importance
# 0           Time_spent_Alone    0.011394
# 1                 Stage_fear    0.186868
# 2    Social_event_attendance    0.006237
# 3              Going_outside    0.003321
# 4  Drained_after_socializing    0.784039
# 5        Friends_circle_size    0.005071
# 6             Post_frequency    0.003071

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def try_params(**params):
    model = RandomForestClassifier(**params, n_jobs=-1, random_state=42)
    model.fit(X_train, X_train_target)
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_val)
    return {"Params": [params], 
            "Train acc": accuracy_score(X_train_target, train_preds), 
            "Val acc": accuracy_score(X_val_target, val_preds),
            "Estimators": model.n_estimators,
            "Depth": model.max_depth,
            "Model": model}

# %%
result = try_params(n_estimators=300, max_depth=15)
result
# Out:
# {'Params': [{'n_estimators': 300, 'max_depth': 15}],
#  'Train acc': 0.9758151587130209,
#  'Val acc': 0.9671777153962428,
#  'Estimators': 300,
#  'Depth': 15,
#  'Model': RandomForestClassifier(max_depth=15, n_estimators=300, n_jobs=-1,
#                         random_state=42)}

# %%
model = result["Model"]

# %%
model
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
rf_preds = model.predict(X_test)

submission = pd.DataFrame({
    "id": X_test_id,        # same order as in test.csv
    "Personality": rf_preds        # your model's predictions
})

submission.to_csv("submission.csv", index=False)

# %%
from xgboost import XGBClassifier

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X_train_target = le.fit_transform(X_train_target)
X_val_target = le.fit_transform(X_val_target)

# %%
def try_params(**params):
    model = XGBClassifier(**params, n_jobs=-1, random_state=42)
    model.fit(X_train, X_train_target)
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_val)
    return {"Params": [params], 
            "Train acc": accuracy_score(X_train_target, train_preds), 
            "Val acc": accuracy_score(X_val_target, val_preds),
            "Estimators": model.n_estimators,
            "Depth": model.max_depth,
            "Model": model}

# %%
result = try_params(learning_rate=0.1, n_estimators=350, max_depth=7)
result
# Out:
# {'Params': [{'learning_rate': 0.1, 'n_estimators': 350, 'max_depth': 7}],
#  'Train acc': 0.9773986899877636,
#  'Val acc': 0.9650183545670482,
#  'Estimators': 350,
#  'Depth': 7,
#  'Model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                feature_weights=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=350,
#                n_jobs=-1, num_parallel_tree=None, ...)}

# %%
model = result["Model"]

# %%
final_preds = model.predict(X_test)
preds = le.inverse_transform(final_preds)

submission = pd.DataFrame({
    "id": X_test_id,        # same order as in test.csv
    "Personality": preds        # your model's predictions
})

submission.to_csv("submission.csv", index=False)
